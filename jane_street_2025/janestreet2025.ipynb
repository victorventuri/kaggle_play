# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ../input/jane-street-real-time-market-data-forecasting/responders.csv
# ../input/jane-street-real-time-market-data-forecasting/features.csv
# ../input/jane-street-real-time-market-data-forecasting/sample_submission.csv
# ../input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=1/part-0.parquet
# ../input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=6/part-0.parquet
# ../input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=8/part-0.parquet
# ../input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=9/part-0.parquet
# ../input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=7/part-0.parquet
# ../input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=0/part-0.parquet
# ../input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=5/part-0.parquet
# ../input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=2/part-0.parquet
# ../input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=3/part-0.parquet
# ../input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id=4/part-0.parquet
# ../input/jane-street-real-time-market-data-forecasting/test.parquet/date_id=0/part-0.parquet
# ../input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/__init__.py
# ../input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/jane_street_inference_server.py
# ../input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/jane_street_gateway.py
# ../input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/kaggle_evaluation.proto
# ../input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/__init__.py
# ../input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/templates.py
# ../input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/base_gateway.py
# ../input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/relay.py
# ../input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/generated/kaggle_evaluation_pb2.py
# ../input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/generated/__init__.py
# ../input/jane-street-real-time-market-data-forecasting/kaggle_evaluation/core/generated/kaggle_evaluation_pb2_grpc.py
# ../input/jane-street-real-time-market-data-forecasting/lags.parquet/date_id=0/part-0.parquet
# ../input/house-prices-advanced-regression-techniques/test.csv
# ../input/house-prices-advanced-regression-techniques/data_description.txt
# ../input/house-prices-advanced-regression-techniques/train.csv
# ../input/house-prices-advanced-regression-techniques/sample_submission.csv
